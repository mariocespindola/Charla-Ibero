# %% [markdown]
# <img src='img/DS.jpg'>
#
# # Data Science
#
# El poder del Big Data y la Ciencia de Datos están revolucionando el mundo. Desde la moderna empresa de negocios hasta las opciones de estilo de vida del ciudadano digital de hoy en día, las perspectivas de la ciencia de datos están impulsando cambios y mejoras en todos los ámbitos. Aunque la ciencia de datos puede ser un tema nuevo para muchos, es una habilidad que cualquier persona que quiera permanecer relevante en su campo profesional y en la industria debe saber.
#
# Desde hace bastante tiempo, todo el mundo ha sido completamente inundado por los datos. Viene de todas las computadoras, dispositivos móviles, cámaras y sensores imaginables, y ahora incluso proviene de relojes y otras tecnologías portátiles. Los datos se generan en cada interacción de redes sociales que hacemos, cada archivo que guardamos, cada imagen que tomamos y cada consulta que enviamos; incluso se genera cuando hacemos algo tan simple como pedirle a un motor de búsqueda favorito las direcciones a la heladería más cercana.
#
# Aunque la inmersión de datos no es nada nuevo, es posible que haya notado que el fenómeno se está acelerando. Los lagos, los charcos y los ríos de datos se han convertido en inundaciones y en verdaderos tsunamis de datos estructurados, semiestructurados y no estructurados que se transmiten desde casi todas las actividades que tienen lugar tanto en el mundo digital como en el físico. ¡Bienvenido al mundo del big data!
#
#
# <img src='img/dataeverywhere.jpg'>
#
#
# **¿Cuál es el punto de todos estos datos?** **¿Por qué usar recursos valiosos para generarlos y recopilarlos?** Aunque hace solo una década, nadie estaba en condiciones de hacer un gran uso de la mayoría de los datos que se generan, las tendencias actuales han cambiado definitivamente. Los especialistas conocidos como ingenieros de datos están encontrando constantemente nuevas formas innovadoras y poderosas para capturar, compaginar y condensar volúmenes de datos inimaginablemente masivos, y otros especialistas, conocidos como científicos de datos, están liderando el cambio al derivar información valiosa y procesable a partir de esos datos.
#
# En su forma más verdadera, la ciencia de datos representa la optimización de procesos y recursos. La ciencia de los datos produce perspectivas de datos: conclusiones o predicciones viables e informadas que puede utilizar para comprender y mejorar su negocio, sus inversiones, su salud e incluso su estilo de vida y su vida social. Usar la información de la ciencia de datos es como poder ver en la oscuridad. Para cualquier objetivo o objetivo que pueda imaginar, puede encontrar métodos de ciencia de datos para ayudarlo a predecir la ruta más directa desde donde se encuentra hasta donde desea estar, y anticipar cada bache en el camino entre ambos lugares.
#
# # Data Science & Data Engineering
#
# **Data science**. Es la ciencia computacional de extraer perspectivas significativas de datos sin procesar y luego comunicarlas de manera efectiva para generar valor.
#
# **Data engineering**. Es un dominio de ingeniería dedicado a crear y mantener sistemas que superan los cuellos de botella en el procesamiento de datos y los problemas de manejo de datos para las aplicaciones que consumen, procesan y almacenan grandes volúmenes, variedades y velocidades de datos.
#
# # Tipos de datos
#
# <img src='img/datatype.jpg'>
#
# **Estructurados**. Los datos se almacenan, procesan y manipulan en un sistema de gestión de base de datos relacional tradicional (RDBMS).
#
# **No estructurados**. Los datos que se generan comúnmente a partir de actividades humanas y no encajan en un formato de base de datos estructurada.
#
# **Semiestructurados**. Los datos no encajan en un sistema de base de datos estructurado, pero aún así están estructurados por etiquetas que son útiles para crear una forma de orden y jerarquía en los datos.
#
# # Quien usa esto?
#
# **Los ingenieros** utilizan machine learning para optimizar la eficiencia energética en el diseño de edificios modernos.
#
# **Los doctores** trabajan en la personalización de los planes de tratamiento y utilizan la informática de la salud para predecir y prevenir problemas de salud futuros en pacientes en riesgo.
#
# **Los mercadologos** utilizan la regresión logística para predecir y evitar la rotación de clientes.
#
# **Los periodistas** rastrean los sitios web para obtener datos nuevos con el fin de descubrir e informar las últimas noticias de última hora.
#
# **Los criminologos** utilizan modelos predictivos espaciales para predecir, prevenir y prevenir actividades delictivas.
#
# **La razita buen pedo** utilizan machine learning para clasificar e informar información vital sobre las comunidades afectadas por el desastre para el apoyo de decisiones en tiempo real en la respuesta humanitaria.
#
# # Roles actuales
#
# **Que tipo de trabajos/roles hay en un pipeline de Data Science?**
#
# <img src='img/dataroles.png'>
#
# Como podemos observar hay 4 roles basicos en el area de Data Science con diferentes enfasis y requerimientos para cada uno.
#
# # Que es Machine Learning?
#
# El Machine Learning evolucionó como un subcampo de Inteligencia Artificial que involucraba algoritmos de autoaprendizaje que derivaban el conocimiento de los datos para hacer predicciones. En lugar de requerir que los humanos deriven reglas manualmente y construyan modelos para analizar grandes cantidades de datos, el aprendizaje automático ofrece una alternativa más eficiente para capturar el conocimiento en datos para mejorar gradualmente el rendimiento de los modelos predictivos y tomar decisiones basadas en datos. El aprendizaje automático no solo es cada vez más importante en la investigación informática, sino que también desempeña un papel cada vez más importante en nuestra vida cotidiana. Gracias al aprendizaje automático, disfrutamos de filtros robustos de correo electrónico no deseado, un software de reconocimiento de voz y de texto conveniente, motores de búsqueda web confiables, desafiantes programas de juego de ajedrez y, con suerte, pronto, autos automáticos seguros y eficientes.
#
# Existen 3 tipos de Machine Learning:
#
# <img src='img/mltypes.png'>

# %%
# Ejemplo 
# Importamos las librerias necesarias
from __future__ import print_function

import sys

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
# %matplotlib inline

import pandas as pd

from sklearn import cluster, covariance, manifold

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# #############################################################################
# Vamos a bajar el dataset de internet

# Los datos son de 2003-2008. Los vamos a obtener de quandl.com y alphavantage.co 

symbol_dict = {
    'TOT': 'Total',
    'XOM': 'Exxon',
    'CVX': 'Chevron',
    'COP': 'ConocoPhillips',
    'VLO': 'Valero Energy',
    'MSFT': 'Microsoft',
    'IBM': 'IBM',
    'TWX': 'Time Warner',
    'CMCSA': 'Comcast',
    'CVC': 'Cablevision',
    'YHOO': 'Yahoo',
    'DELL': 'Dell',
    'HPQ': 'HP',
    'AMZN': 'Amazon',
    'TM': 'Toyota',
    'CAJ': 'Canon',
    'SNE': 'Sony',
    'F': 'Ford',
    'HMC': 'Honda',
    'NAV': 'Navistar',
    'NOC': 'Northrop Grumman',
    'BA': 'Boeing',
    'KO': 'Coca Cola',
    'MMM': '3M',
    'MCD': 'McDonald\'s',
    'PEP': 'Pepsi',
    'K': 'Kellogg',
    'UN': 'Unilever',
    'MAR': 'Marriott',
    'PG': 'Procter Gamble',
    'CL': 'Colgate-Palmolive',
    'GE': 'General Electrics',
    'WFC': 'Wells Fargo',
    'JPM': 'JPMorgan Chase',
    'AIG': 'AIG',
    'AXP': 'American express',
    'BAC': 'Bank of America',
    'GS': 'Goldman Sachs',
    'AAPL': 'Apple',
    'SAP': 'SAP',
    'CSCO': 'Cisco',
    'TXN': 'Texas Instruments',
    'XRX': 'Xerox',
    'WMT': 'Wal-Mart',
    'HD': 'Home Depot',
    'GSK': 'GlaxoSmithKline',
    'PFE': 'Pfizer',
    'SNY': 'Sanofi-Aventis',
    'NVS': 'Novartis',
    'KMB': 'Kimberly-Clark',
    'R': 'Ryder',
    'GD': 'General Dynamics',
    'RTN': 'Raytheon',
    'CVS': 'CVS',
    'CAT': 'Caterpillar',
    'DD': 'DuPont de Nemours'}


symbols, names = np.array(sorted(symbol_dict.items())).T

quotes = []

for symbol in symbols:
    print('Fetching quote history for %r' % symbol, file=sys.stderr)
    url = ('https://raw.githubusercontent.com/scikit-learn/examples-data/'
           'master/financial-data/{}.csv')
    quotes.append(pd.read_csv(url.format(symbol)))

close_prices = np.vstack([q['close'] for q in quotes])
open_prices = np.vstack([q['open'] for q in quotes])

# Las variaciones diarias de las citas son las que llevan más información.
variation = close_prices - open_prices


# #############################################################################
# Aprender una estructura gráfica a partir de las correlaciones.
edge_model = covariance.GraphicalLassoCV(cv=5)

# estandarizamos las series de tiempo: usar correlaciones en lugar de covarianza 
# es más eficiente para la recuperación de estructuras
X = variation.copy().T
X /= X.std(axis=0)
edge_model.fit(X)

# #############################################################################
# Clúster utilizando propagación por afinidad.

_, labels = cluster.affinity_propagation(edge_model.covariance_)
n_labels = labels.max()

for i in range(n_labels + 1):
    print('Cluster %i: %s' % ((i + 1), ', '.join(names[labels == i])))

# #############################################################################
# Encuentre una incorporación de baja dimensión para la visualización: 
# encuentre la mejor posición de los nodos (las existencias) en un plano 2D

# Utilizamos un eigen_solver denso para lograr reproducibilidad. 
# Además, utilizamos un gran número de vecinos para capturar la estructura a gran escala.
node_position_model = manifold.LocallyLinearEmbedding(
    n_components=2, eigen_solver='dense', n_neighbors=6)

embedding = node_position_model.fit_transform(X.T).T
# Out:
# Fetching quote history for 'AAPL'
# Fetching quote history for 'AIG'
# Fetching quote history for 'AMZN'
# Fetching quote history for 'AXP'
# Fetching quote history for 'BA'
# Fetching quote history for 'BAC'
# Fetching quote history for 'CAJ'
# Fetching quote history for 'CAT'
# Fetching quote history for 'CL'
# Fetching quote history for 'CMCSA'
# Fetching quote history for 'COP'
# Fetching quote history for 'CSCO'
# Fetching quote history for 'CVC'
# Fetching quote history for 'CVS'
# Fetching quote history for 'CVX'
# Fetching quote history for 'DD'
# Fetching quote history for 'DELL'
# Fetching quote history for 'F'
# Fetching quote history for 'GD'
# Fetching quote history for 'GE'
# Fetching quote history for 'GS'
# Fetching quote history for 'GSK'
# Fetching quote history for 'HD'
# Fetching quote history for 'HMC'
# Fetching quote history for 'HPQ'
# Fetching quote history for 'IBM'
# Fetching quote history for 'JPM'
# Fetching quote history for 'K'
# ...

# %%
# #############################################################################
# Visualizacion
plt.figure(1, facecolor='w', figsize=(10, 8))
plt.clf()
ax = plt.axes([0., 0., 1., 1.])
plt.axis('off')

# Mostrar un gráfico de las correlaciones parciales.
partial_correlations = edge_model.precision_.copy()
d = 1 / np.sqrt(np.diag(partial_correlations))
partial_correlations *= d
partial_correlations *= d[:, np.newaxis]
non_zero = (np.abs(np.triu(partial_correlations, k=1)) > 0.02)

# Grafica los nodos usando las coordenadas de nuestra incrustación.
plt.scatter(embedding[0], embedding[1], s=100 * d ** 2, c=labels,
            cmap=plt.cm.nipy_spectral)

# Trazamos los bordes
start_idx, end_idx = np.where(non_zero)
# una secuencia de (*line0*, *line1*, *line2*), donde::
#            linen = (x0, y0), (x1, y1), ... (xm, ym)
segments = [[embedding[:, start], embedding[:, stop]]
            for start, stop in zip(start_idx, end_idx)]
values = np.abs(partial_correlations[non_zero])
lc = LineCollection(segments,
                    zorder=0, cmap=plt.cm.hot_r,
                    norm=plt.Normalize(0, .7 * values.max()))
lc.set_array(values)
lc.set_linewidths(15 * values)
ax.add_collection(lc)

# Añade una etiqueta a cada nodo. El desafío aquí es que queremos 
# colocar las etiquetas para evitar que se superpongan con otras etiquetas
for index, (name, label, (x, y)) in enumerate(
        zip(names, labels, embedding.T)):

    dx = x - embedding[0]
    dx[index] = 1
    dy = y - embedding[1]
    dy[index] = 1
    this_dx = dx[np.argmin(np.abs(dy))]
    this_dy = dy[np.argmin(np.abs(dx))]
    if this_dx > 0:
        horizontalalignment = 'left'
        x = x + .002
    else:
        horizontalalignment = 'right'
        x = x - .002
    if this_dy > 0:
        verticalalignment = 'bottom'
        y = y + .002
    else:
        verticalalignment = 'top'
        y = y - .002
    plt.text(x, y, name, size=10,
             horizontalalignment=horizontalalignment,
             verticalalignment=verticalalignment,
             bbox=dict(facecolor='w',
                       edgecolor=plt.cm.nipy_spectral(label / float(n_labels)),
                       alpha=.6))

plt.xlim(embedding[0].min() - .15 * embedding[0].ptp(),
         embedding[0].max() + .10 * embedding[0].ptp(),)
plt.ylim(embedding[1].min() - .03 * embedding[1].ptp(),
         embedding[1].max() + .03 * embedding[1].ptp())

plt.show()

# %% [markdown]
# # The Robots are here!
#
# <img src='img/robots.jpg'>
#
# # Artificial Intelligence in Finance
#
# ![alt text](https://thefinancialbrand.com/wp-content/uploads/2017/09/AI_applications_in_financial_services-565x613.png "Logo Title Text 1")
#
# - La industria financiera es pionera en la adopcion de la Inteligencia Artificial.
# - Los bancos estan adoptando la Inteligencia Artificial para cumplir con todas las regulaciones y para reducir los costos humanos al maximo.
# - Citigroup ha estimado que los bancos gastan 270 mil millones de dolares cada ano en regulacion y compliance lo que equivale al 10% de sus costos operativos.
#
# ![alt text](https://thefinancialbrand.com/wp-content/uploads/2017/10/AI_solution_deployment_blog_96_dpi-565x454.png "Logo Title Text 1")
#
# - La reduccion de costos en 2019 se basa 100% en la automatizacion.
# - 90% de los datos que se generaron en el mundo se coletaron entre 2016-2018.
# - Las tareas repetitivas que requieren muchos recursos, como la entrada de datos y el procesamiento de transacciones, son muy adecuadas para la automatización y la inteligencia artificial..
# - Los CFO de las grandes empresas y emprendedores deben buscar formas de utilizar AI para mejorar FinTech (planificación, presupuesto y previsión, informes financieros, contabilidad operativa, asignaciones y ajustes, conciliaciones, transacciones intercompañías)
#
# ![alt text](https://bluenotes.anz.com/content/dam/bluenotes/images/articles/2016/June/sibsonrizzo_ai-bakermckenzie_infog2.png/_jcr_content/renditions/original "Logo Title Text 1")
#
# ### El mercado de la inteligencia artificial en los servicios financieros crecera de 1.300 millones en 2017 a 7.400 millones en 2022, con una tasa de crecimiento anual compuesta del 40,4%
#
# ![alt text](https://cdn-images-1.medium.com/max/1600/1*jsmP9AHF5c7_vBaFLpefsQ.png "Logo Title Text 1")
#
# ## Problemas con la integración de la Inteligencia Artificial.
#
# ![alt text](https://thefinancialbrand.com/wp-content/uploads/2017/02/barriers_to_digital_transformation_banking-565x443.png "Logo Title Text 1")
#
# - Sistemas viejos que nos comunican entre ellos.
# - Preocupaciones sobre la privacidad.
# - Silos de datos.
# - Falta de personal capacitado.
# - El esfuerzo laborioso de entrenar modelos supervisados.
# - Falta de alineación cultural.
# - Posible sesgo del aprendizaje automático.
# - Decidir entre proveedor de nube, construcción interna, código abierto o tecnología patentada?
#
# ![alt text](https://dashbouquet.com/assets/img/blog/AI-in-FinTech-Market-Map-Image.png "Logo Title Text 1")
#
# ## Aplicaciones
#
# ![alt text](https://qph.fs.quoracdn.net/main-qimg-fcb631ba245b7d74fab2f851fba7093d-c "Logo Title Text 1")
#
# #### Aumentando la seguridad
#
# ![alt text](https://d279iyy6fmg6l4.cloudfront.net/blog/fraud-detection-in-banking.png "Logo Title Text 1")
#
# - Comportamiento fraudulento, transacciones sospechosas, posibles ataques futuros. Como se puede mitigar esto?
# - La Inteligencia Artificial puede analizar grandes volúmenes de datos de seguridad y escalar al tamaño de una empresa a medida que crece
# - Cada vez mas se almacenan datos en linea.
# - Utilizando Machine Learning, los sistemas pueden detectar actividades o comportamientos únicos ("anomalías") y marcarlos para los equipos de seguridad.
# - Dada la incalculablemente alta cantidad de formas en que se puede violar la seguridad, los sistemas de "aprendizaje" genuinos serán una necesidad en los próximos cinco a diez años.
# - Según un estudio realizado en 2015 por la firma de investigación Javelin Strategy, las falsas disminuciones, las transacciones legítimas que se rechazan erróneamente, representan 118 millones de pérdidas para los minoristas.
# - Un tercio de los casos de declinación falsa se traduce en clientes perdidos, y solo en EE. UU. Incurren en daños que tienen un valor 13 veces mayor que el fraude real.
# - Al analizar varios puntos de datos, los algoritmos de Machine Learning pueden detectar transacciones fraudulentas que podrían pasar inadvertidas para los analistas humanos al tiempo que mejoran la precisión de las aprobaciones en tiempo real y reducen las falsas disminuciones.
#
# ![alt text](https://newsroom.mastercard.com/wp-content/uploads/2016/11/MasterCard-decision-intelligence-infographic.V.6_TwitterCards.png "Logo Title Text 1")
#
# - Mastercard ha lanzado recientemente su tecnologia Decision Intelligence.
# - En lugar de limitarse a las reglas predefinidas, DI recoge patrones de compras históricas y hábitos de gasto de los titulares de tarjetas para establecer una línea de base de comportamiento con la que comparará y calificará cada nueva transacción.
#
# ![alt text](https://gigaom.com/wp-content/uploads/sites/1/2013/03/siftscience.jpg "Logo Title Text 1")
#
# - Sift Science recopila datos de más de 6,000 sitios web donde se implementa su solución de detección de fraudes.
# - Esto le permite rastrear y analizar datos a través de múltiples canales y dispositivos
#
# #### Reduciendo los tiempos de procesamiento
#
# ![alt text](https://cdn-images-1.medium.com/max/2000/1*MfGMH7gnYgFd_NrLIUC7gA.png "Logo Title Text 1")
#
# - El procesamiento de recibos y otra documentación financiera requiere mucho tiempo;
# - Requiere la paciencia y la perseverancia de múltiples recursos y es una de esas tareas necesarias que a menudo son propensas al error humano.
# - https://www.parascript.com/receipt-capture/ hace esto
#
# #### Trading
#
# ![alt text](http://www.turingfinance.com/wp-content/uploads/2013/11/Algorithmic-Trading-Systems-Conceptual.png "Logo Title Text 1")
#
# - Algorithmic trading implica el uso de sistemas complejos de inteligencia artificial para tomar decisiones comerciales extremadamente rápidas. (originado en los 70s)
# - Los sistemas algorítmicos a menudo realizan miles o millones de transacciones en un día, de ahí el término High Frequency Trading, que se considera un subconjunto de la negociación algorítmica.
# - La mayoría de los Hedge Funds y las instituciones financieras no revelan abiertamente sus enfoques de Inteligencia Artificial para el comercio, pero el Machine Learning y el Deep Learning juegan un papel cada vez más importante en la calibración de las decisiones comerciales en tiempo real
# - El mercado de valores se mueve en respuesta a una gran cantidad de factores relacionados con los humanos que no tienen nada que ver con los símbolos ticker, y la esperanza es que el Machine Learning pueda replicar y mejorar la "intuición" humana de la actividad financiera al descubrir nuevas tendencias y señales reveladoras.
# - Algunos hedge funds populares que utilizan la Inteligencia Artificial incluyen - Two Sigma, LLC, PDT Partners, DE Shaw, Man AHL, Citadel, Vatic Labs, Point72, Cubist etc.
#
# ![alt text](https://cdn.sentient.ai/wp-content/uploads/2015/11/Creating_Genes_Slide_01.jpg "Logo Title Text 1")
#
# - Sentient Technologies, una empresa de Inteligencia Artificial en San Francisco que tiene un hedge fund, ha desarrollado un algoritmo que consume millones de datapoints para encontrar patrones y hacer pronosticos, lo que le permite hacer mejores decisiones de trading.
# - Sentient ejecuta billones de escenarios comerciales simulados creados a partir de las vastas cantidades de datos públicos disponibles en línea.
# - Exprime 1,800 días de trading en unos pocos minutos.
# - Las estrategias comerciales exitosas, que se denominan "genes", luego se prueban en el comercio en vivo, donde evolucionan de manera autónoma a medida que ganan experiencia.
#
# ![alt text](https://s3.fintastico.com/media/CACHE/images/numerai-screenshot_756/507ca3ac16b727303ec3f180bd343adf.jpg "Logo Title Text 1")
#
# - Numerai Utiliza la Inteligencia Artificial para tomar decisiones de trading.
# - En lugar de desarrollar los algoritmos en sí mismos, han subcontratado la tarea a miles de científicos de datos anónimos, que compiten para crear los mejores algoritmos y ganar la criptomoneda por sus esfuerzos.
# - Comparten datos de trading con los científicos de datos de una manera que les impide replicar las operaciones del fondo y, al mismo tiempo, les permite crear modelos para mejores operaciones.
#
# #### Prestamos de credito
#
# ![alt text](https://image.slidesharecdn.com/richardharris-feedzai-161117114315/95/using-machine-learning-ai-to-enhance-fraud-detection-21-638.jpg?cb=1479383034 "Logo Title Text 1")
#
# - Los algoritmos de Machine Learning pueden capacitarse en millones de ejemplos de datos de consumidores (edad, trabajo, estado civil, etc.) y préstamos financieros o resultados de seguros (esta persona no pagó, pagó el préstamo a tiempo, tuvo un accidente automovilístico, etc.). ...?).
# - Las tendencias pueden analizarse continuamente para detectar tendencias que podrían influir en los préstamos y asegurar el futuro (¿hay más y más jóvenes en cierto estado que entran en accidentes automovilísticos? ¿Hay tasas de incumplimiento cada vez mayores entre una población demográfica específica en los últimos 15 años?
# - Los sistemas tradicionales se basaron en datos históricos como el historial de transacciones, el historial de crédito y el crecimiento de los ingresos a lo largo de los años para comprender el riesgo asociado con cada préstamo otorgado.
# - Esto resulta en estimaciones inconsistentes, ya que los datos históricos no siempre son un estándar preciso para predecir el comportamiento futuro.
# - El Machine learning permite el análisis de datos en tiempo real de transacciones recientes, condiciones del mercado e incluso las últimas noticias para identificar riesgos potenciales en la oferta de crédito.
# - Con la ayuda del análisis predictivo, un algoritmo de Machine Learning puede analizar petabytes de datos para comprender las micro actividades y evaluar el comportamiento de las partes para identificar un posible fraude.
# - Esto es algo imposible de realizar manualmente para los inversores humanos.
# - Zestfinance hace esto https://www.zestfinance.com/zaml
#
# #### Portfolio Management
#
# <img src='img/portfoliomanagement.png'>
#
# - El término "robo-advisor" fue esencialmente inaudito hace apenas cinco años, pero ahora es un lugar común en el panorama financiero.
# - Estos son algoritmos creados para calibrar una cartera financiera con los objetivos y la tolerancia al riesgo del usuario.
# - Los usuarios ingresan sus metas (por ejemplo, retirarse a los 65 años con 250,000.00 en ahorros), edad, ingresos y activos financieros actuales.
# - El "robo-advisor" luego distribuye las inversiones a través de clases de activos e instrumentos financieros para alcanzar los objetivos del usuario.
# - Luego, el sistema se calibra a los cambios en los objetivos del usuario y a los cambios en tiempo real en el mercado, con el objetivo de encontrar siempre la mejor opción para los objetivos originales del usuario.
# - Los "robo-advisors" han ganado una importante tracción con los consumidores millennials que no necesitan un asesor físico para sentirse cómodos invirtiendo
# - De manera similar, las aplicaciones de inteligencia financiera personal habilitadas con Inteligencia Artificial están ayudando a los consumidores a administrar sus finanzas, analizar los gastos, automatizar la presentación de formularios de impuestos y hacer recomendaciones financieras con un modelo de negocio no basado en la generación de comisiones por inversiones.
# - Responsive.ai hace esto http://alpha.responsive.ai/
